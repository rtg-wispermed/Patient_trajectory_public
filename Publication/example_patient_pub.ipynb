# %%
## Public try uploads directly the translated_cleaned.json file
import sys
import json


try:
    sys.path.insert(0,'/groups/dso/meijie/melanoma_data/Patient_history/patient-history/Publication/extraction_funs_pub')
    sys.path.insert(0,'/groups/dso/meijie/melanoma_data/fhir_data/Top2000Melanomexport-2022-04-30T10:49:34')
    sys.path.insert(0,'/groups/dso/meijie/melanoma_data/fhir_data_pub')
except ImportError:
    sys.path.insert(0,'extraction_funs_pub')

from medication_extractor import *
from tnm_extractors import *
from extraction_baseclass import extractor, tryPath
from group_and_merge import groupResources, combineResources
from procedure_extractors import *
from condition_extractor import *
from careplan_extractor import *
from os import listdir
from itertools import chain

ptnm_extractor = getExtractorPTNM()
ctnm_extractor = getExtractorCTNM()
medi_extractor = getMedicationAdministration()
radiotherapy_ext = getRadioTherapy()
surgeries_ext = getOperation()
examinations_ext = getExaminations()
progress_extractor = getExtractorProgress()
tproperties_extractor = getExtractorPropertiesPrimary()

json_path_to_cleaned_patient = '/groups/dso/meijie/melanoma_data/fhir_data/translated_cleaned.json'
with open(json_path_to_cleaned_patient) as f:
    data = json.load(f)

resources = json.load(open(json_path_to_cleaned_patient))['entry']
resources
# Out:
# [{'resource': {'resourceType': 'condition',
#    'id': 'bd9cd822-0b58-4f6f-9db4-de257b41426d',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/PrimaryTumorDiagnosis'}],
#    'verificationStatus': {'extension': [{'url': 'https://hospital.org/TumorDocumentation/PrimaryTumorDiagnosis/ConfirmationOfDiagnosis',
#       'valueCoding': {'system': 'https://hospital.org/TumorDocumentation/PrimaryTumorDiagnosis/ConfirmationOfDiagnosis',
#        'code': 'H',
#        'display': 'Histology of the primary tumor'}}],
#     'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed',
#       'display': 'Confirmed'}]},
#    'code': {'coding': [{'system': 'http://fhir.de/CodeSystem/dimdi/icd-10-gm',
#       'version': 'ICD10_2014',
#       'code': 'C43.7',
#       'display': 'Malignant melanoma of the lower limb, including the hip'}]},
#    'bodySite': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '24028007',
#        'display': 'Right'}]},
#     {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/icd-o-3',
#        'code': 'C44.7',
#        'display': 'skin of thighs'}]}],
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'onsetDateTime': '2013-12',
#    'stage': [{'type': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '50283003',
#         'display': 'Clinical stage III'}]}},
#     {'type': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '2640006',
#         'display': 'Clinical stage IV'}]}},
#     {'assessment': [{'reference': 'Observation/56102040-deb5-4a4e-a8a5-343dbd5dd137'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21908-9',
#         'display': 'Stage group. Clinical Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/accbfeb5-8d3c-42c5-b552-607a6b700e92'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21908-9',
#         'display': 'Stage group. Clinical Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/8491c3b2-6c1a-48a9-b41e-55668bf607f4'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/83f69e2c-f64c-4b2b-b2a5-63af8b60ce8b'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/2fc29f9a-d98f-4007-93e9-8a49aefc19d7'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/13d95237-f0d0-4036-8bbe-7e3c1714f502'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/c6fe928f-5b79-40fd-b1fe-af0487788bb6'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/05ee9049-f772-4844-be01-377e58244a7e'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/2fa62a5d-2206-4b55-afc5-2731577b8b1c'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}},
#     {'assessment': [{'reference': 'Observation/f84c9ecf-c883-47bb-860f-1f249c6b31b7'}],
#      'type': {'coding': [{'system': 'http://loinc.org',
#         'code': '21902-2',
#         'display': 'Stage group. pathology Cancer'}]}}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '778abf37-0f5a-4701-aca8-22f9ed9d3975',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '55207-5',
#       'display': 'Genetic analysis discrete result panel'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'hasMember': [{'reference': 'Observation/44ceb3f9-0505-4771-a5cf-b5d3b2d167ce'},
#     {'reference': 'Observation/6713bf38-3ff1-471d-bcc9-05f054f9df0c'},
#     {'reference': 'Observation/33ae9700-ba8b-419c-a394-76ed02ae8899'},
#     {'reference': 'Observation/c762baa9-946f-4a8d-b73a-2c0be9ad1452'},
#     {'reference': 'Observation/7b54e970-60f8-469e-85fa-bcf65b1a0d14'},
#     {'reference': 'Observation/a15f31db-1fea-4c00-ad7c-a849bc6b958f'},
#     {'reference': 'Observation/ce52f7bd-5d5a-48bc-b940-8f99fd586b13'},
#     {'reference': 'Observation/c196aaa8-02fb-4a2f-80d3-099a6f4e28ac'},
#     {'reference': 'Observation/ada02139-5004-46b3-8ac6-085ab8ebac5e'},
#     {'reference': 'Observation/5e44ef51-fec8-4b06-aa3b-db781770458b'},
#     {'reference': 'Observation/249ec766-fd80-4736-98b5-1ca6c06a1d51'},
#     {'reference': 'Observation/a994dadb-0aea-49e3-9c77-3e30edfff41e'},
#     {'reference': 'Observation/de931148-68e1-47c6-8bc6-4172b47013df'},
#     {'reference': 'Observation/3a63d752-978f-4d94-8f64-2cf090b91e98'},
#     {'reference': 'Observation/235c7558-519c-4bf8-8a1c-24d40c24b62e'},
#     {'reference': 'Observation/cf6392b0-8cc6-49ef-a2db-ec7f06a0306d'},
#     {'reference': 'Observation/0a163d06-7ab0-4484-8774-8cd877c2206a'},
#     {'reference': 'Observation/9337eba0-9fbd-4370-aa5f-1a89103af80a'},
#     {'reference': 'Observation/8eab70bc-00ad-48af-93ce-2c064e825740'},
#     {'reference': 'Observation/74020375-94af-45bd-a033-3daf0a848db4'},
#     {'reference': 'Observation/347892cf-35ac-4e3a-9a19-585ae6ad04cb'},
#     {'reference': 'Observation/e7257186-cc80-44ce-8839-34cc9045f73c'},
#     {'reference': 'Observation/0adfa9fa-2a94-4a03-98c6-c2c555f00def'},
#     {'reference': 'Observation/4c51401e-20ae-486b-8d2f-9c3fee122a43'},
#     {'reference': 'Observation/bdb9a409-efbb-4a4c-b07d-d821344caabe'},
#     {'reference': 'Observation/04940209-900f-404d-8adb-dcdbdbb31f5b'},
#     {'reference': 'Observation/28ce8eb9-364d-40e7-8aba-32db4b4b4c96'},
#     {'reference': 'Observation/aeec9d57-9db6-4ece-af95-c5fe5b63accb'},
#     {'reference': 'Observation/37dc45bc-9279-438f-adb9-44de49b05c27'},
#     {'reference': 'Observation/c162cf62-c7e0-4380-a9ef-e8d9d4632f4b'}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '235c7558-519c-4bf8-8a1c-24d40c24b62e',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG12ER',
#       'display': 'CDK4 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'bdb9a409-efbb-4a4c-b07d-d821344caabe',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG17ER',
#       'display': 'PIK3R1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'a994dadb-0aea-49e3-9c77-3e30edfff41e',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG9ER',
#       'display': 'TERT result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '3a63d752-978f-4d94-8f64-2cf090b91e98',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG14ER',
#       'display': 'TP53 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '347892cf-35ac-4e3a-9a19-585ae6ad04cb',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG25ER',
#       'display': 'CTNNB1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'patient',
#    'id': '02b4f296-3cfc-4e2b-a35c-70c83712160b',
#    'meta': {'profile': ['https://www.medizininformatik-initiative.de/fhir/core/modul-person/StructureDefinition/Patient',
#      'https://gematik.de/fhir/ISiK/StructureDefinition/ISiKPatient']},
#    'identifier': [{'use': 'usual',
#      'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR'}]},
#      'system': 'https://hospital.org/HIS/Cerner/Medico'},
#     {'use': 'official',
#      'type': {'coding': [{'system': 'http://fhir.de/CodeSystem/identifier-type-de-basis',
#         'code': 'GKV'}]},
#      'system': 'http://fhir.de/NamingSystem/gkv/kvid-10',
#      'assigner': {'identifier': {'use': 'official',
#        'system': 'http://fhir.de/NamingSystem/arge-ik/iknr'}}}],
#    'gender': 'female',
#    'birthDate': '1961-05-30',
#    'deceasedDateTime': '2019-06-21T19:41:57.025+02:00',
#    'managingOrganization': {'reference': 'Organization/78a70a18-6868-463e-b4c0-b50de7e72ab0'}}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'ce52f7bd-5d5a-48bc-b940-8f99fd586b13',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG27ER',
#       'display': 'WT1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '5e44ef51-fec8-4b06-aa3b-db781770458b',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG15ER',
#       'display': 'MAP2K1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '7b54e970-60f8-469e-85fa-bcf65b1a0d14',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG23ER',
#       'display': 'EZH2 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '74020375-94af-45bd-a033-3daf0a848db4',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG3ER',
#       'display': 'KIT result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'a15f31db-1fea-4c00-ad7c-a849bc6b958f',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG19ER',
#       'display': 'MITF result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '4c51401e-20ae-486b-8d2f-9c3fee122a43',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG16ER',
#       'display': 'MAP2K2 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '0a163d06-7ab0-4484-8774-8cd877c2206a',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG28ER',
#       'display': 'BAP1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'c762baa9-946f-4a8d-b73a-2c0be9ad1452',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG2ER',
#       'display': 'NRAS result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'aeec9d57-9db6-4ece-af95-c5fe5b63accb',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG10ER',
#       'display': 'hTERT result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'c162cf62-c7e0-4380-a9ef-e8d9d4632f4b',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG7ER',
#       'display': 'HRAS result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'de931148-68e1-47c6-8bc6-4172b47013df',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG4ER',
#       'display': 'GNAQ result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '28ce8eb9-364d-40e7-8aba-32db4b4b4c96',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG21ER',
#       'display': 'ARID1A result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '8eab70bc-00ad-48af-93ce-2c064e825740',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG11ER',
#       'display': 'CDKN2A result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '0adfa9fa-2a94-4a03-98c6-c2c555f00def',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG13ER',
#       'display': 'PTEN result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '6713bf38-3ff1-471d-bcc9-05f054f9df0c',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG22ER',
#       'display': 'SMARCA4 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '37dc45bc-9279-438f-adb9-44de49b05c27',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG29ER',
#       'display': 'SF3B1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '33ae9700-ba8b-419c-a394-76ed02ae8899',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG8ER',
#       'display': 'RAC1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'cf6392b0-8cc6-49ef-a2db-ec7f06a0306d',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG20ER',
#       'display': 'ARID2 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '44ceb3f9-0505-4771-a5cf-b5d3b2d167ce',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG24ER',
#       'display': 'IDH1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'ada02139-5004-46b3-8ac6-085ab8ebac5e',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG30ER',
#       'display': 'KRAS result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '9337eba0-9fbd-4370-aa5f-1a89103af80a',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG6ER',
#       'display': 'NF1 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'c196aaa8-02fb-4a2f-80d3-099a6f4e28ac',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG26ER',
#       'display': 'FBXW7 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '249ec766-fd80-4736-98b5-1ca6c06a1d51',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG5ER',
#       'display': 'GNA11 result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'e7257186-cc80-44ce-8839-34cc9045f73c',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG1ER',
#       'display': 'BRAF result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'C0730319',
#       'display': 'Genetics Finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643461'}]}],
#    'component': [{'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Frequency',
#         'code': 'B1AAYPBG1FR',
#         'display': 'BRAF frequency'}]},
#      'valueInteger': 44}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '04940209-900f-404d-8adb-dcdbdbb31f5b',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG18ER',
#       'display': 'PIK3CA result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2015-12-14',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'Organization',
#    'id': '78a70a18-6868-463e-b4c0-b50de7e72ab0',
#    'identifier': [{'system': 'https://hospital.org/HIS/Cerner/Medico'}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'b386de91-2447-4716-b2ba-9e8181975273',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '55207-5',
#       'display': 'Genetic analysis discrete result panel'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2013',
#    'hasMember': [{'reference': 'Observation/96522a38-0b17-4fd9-aa26-ca9b8c3b0468'},
#     {'reference': 'Observation/b24d19af-826f-4040-b99a-78930319af54'}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'b24d19af-826f-4040-b99a-78930319af54',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG1ER',
#       'display': 'BRAF result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2013',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'C0730319',
#       'display': 'Genetics Finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643461'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '96522a38-0b17-4fd9-aa26-ca9b8c3b0468',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/MutationStatus/Oncogene',
#       'code': 'B1AAYPBG2ER',
#       'display': 'NRAS result'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2013',
#    'valueCodeableConcept': {'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'CL1643496',
#       'display': 'Wild type finding'}]},
#    'interpretation': [{'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#        'code': 'CL1643464'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '58ef1a49-0fcb-4641-99ab-4891b5942298',
#    'meta': {'profile': ['http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy']},
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/RadiationTherapy/nNGM'}],
#    'status': 'completed',
#    'statusReason': {'coding': [{'system': 'https://www.hospital.org/nngm/CodeSystem/ST_Ende_Grund',
#       'code': 'Miscellaneous',
#       'display': 'Miscellaneous'}]},
#    'category': {'coding': [{'system': 'http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy',
#       'code': 'radiotherapy'},
#      {'system': 'http://snomed.info/sct',
#       'code': '108290001',
#       'display': 'Radiation oncology AND/OR radiotherapy'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '33195004',
#       'display': 'External beam radiation therapy procedure'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedPeriod': {'start': '2019-03-21', 'end': '2019-03-21'},
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'palliative',
#        'display': 'palliative'},
#       {'system': 'http://snomed.info/sct', 'code': '363676003'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '0de06efb-5212-4072-9a3a-56799848048c',
#    'meta': {'profile': ['http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy']},
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/RadiationTherapy/nNGM'}],
#    'status': 'completed',
#    'statusReason': {'coding': [{'system': 'https://www.hospital.org/nngm/CodeSystem/ST_Ende_Grund',
#       'code': 'Miscellaneous',
#       'display': 'Miscellaneous'}]},
#    'category': {'coding': [{'system': 'http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy',
#       'code': 'radiotherapy'},
#      {'system': 'http://snomed.info/sct',
#       'code': '108290001',
#       'display': 'Radiation oncology AND/OR radiotherapy'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '33195004',
#       'display': 'External beam radiation therapy procedure'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedPeriod': {'start': '2019-03-21', 'end': '2019-03-21'},
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'palliative',
#        'display': 'palliative'},
#       {'system': 'http://snomed.info/sct', 'code': '363676003'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '39ca4667-2ffe-45b8-bcd1-675679547685',
#    'meta': {'profile': ['http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy']},
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/RadiationTherapy/nNGM'}],
#    'status': 'completed',
#    'statusReason': {'coding': [{'system': 'https://www.hospital.org/nngm/CodeSystem/ST_Ende_Grund',
#       'code': 'regular ending',
#       'display': 'regular ending'}]},
#    'category': {'coding': [{'system': 'http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy',
#       'code': 'radiotherapy'},
#      {'system': 'http://snomed.info/sct',
#       'code': '108290001',
#       'display': 'Radiation oncology AND/OR radiotherapy'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '33195004',
#       'display': 'External beam radiation therapy procedure'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedPeriod': {'start': '2017-02-24', 'end': '2017-02-28'},
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'palliative',
#        'display': 'palliative'},
#       {'system': 'http://snomed.info/sct', 'code': '363676003'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '94afd881-08ca-4364-92ab-3e623af5e8e2',
#    'meta': {'profile': ['http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy']},
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/RadiationTherapy/nNGM'}],
#    'status': 'completed',
#    'statusReason': {'coding': [{'system': 'https://www.hospital.org/nngm/CodeSystem/ST_Ende_Grund',
#       'code': 'regular ending',
#       'display': 'regular ending'}]},
#    'category': {'coding': [{'system': 'http://hospital.org/fhir/StructureDefinition/Procedure/nNGM/Radiotherapy',
#       'code': 'radiotherapy'},
#      {'system': 'http://snomed.info/sct',
#       'code': '108290001',
#       'display': 'Radiation oncology AND/OR radiotherapy'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '33195004',
#       'display': 'External beam radiation therapy procedure'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedPeriod': {'start': '2016-06', 'end': '2016-06-29'},
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'palliative',
#        'display': 'palliative'},
#       {'system': 'http://snomed.info/sct', 'code': '363676003'}]},
#     {'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'adjuvant',
#        'display': 'adjuvant'},
#       {'system': 'http://snomed.info/sct', 'code': '373846009'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'b1ffdaf6-16e9-401c-81f0-de91dc64a491',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/RiskFactors'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'social history',
#        'display': 'SocialHistory'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/RiskFactors',
#       'code': 'B1AANFAHA',
#       'display': 'Familial burden of skin cancer'},
#      {'system': 'http://snomed.info/sct',
#       'code': '429405004',
#       'display': 'Family history of malignant neoplasm of skin (situation)'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'valueBoolean': True}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '787876a5-513a-4f35-b22a-2eeb196de40e',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/Operation/nNGM'}],
#    'status': 'completed',
#    'code': {'extension': [{'url': 'http://hospital.org/fhir/StructureDefinition/Extension/nNGM/resektion',
#       'extension': [{'url': 'resection type',
#         'valueCodeableConcept': {'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/OperationArtResektion',
#            'code': 'resection of metastases'}]}}]}],
#     'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'C15329',
#       'display': 'Surgical Procedure'},
#      {'system': 'https://hospital.org/TumorDocumentation/Operation/OPS',
#       'version': 'OPS301_2016',
#       'code': '5-895.0e'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedDateTime': '2013-12',
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'curative',
#        'display': 'curative'}]}],
#    'bodySite': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '68367000',
#        'display': 'thigh'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '43295168-27ec-4d18-ada5-5e62aa3b8848',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/Operation/nNGM'}],
#    'status': 'completed',
#    'code': {'extension': [{'url': 'http://hospital.org/fhir/StructureDefinition/Extension/nNGM/art-des-eingriffs',
#       'valueCodeableConcept': {'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/ngnm/OperationArtDesEingriffs',
#          'code': 'metastatic resection'}]}}],
#     'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'C15329',
#       'display': 'Surgical Procedure'},
#      {'system': 'https://hospital.org/TumorDocumentation/Operation/OPS',
#       'version': 'OPS301_2015',
#       'code': '5-895.2e'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedDateTime': '2015-12-11',
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'palliative',
#        'display': 'palliative'}]}],
#    'bodySite': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '68367000',
#        'display': 'thigh'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': 'e074fb11-4c01-4de2-bd2e-41f0d329515f',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/Operation/nNGM'}],
#    'status': 'completed',
#    'code': {'extension': [{'url': 'http://hospital.org/fhir/StructureDefinition/Extension/nNGM/art-des-eingriffs',
#       'valueCodeableConcept': {'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/ngnm/OperationArtDesEingriffs',
#          'code': 'metastatic resection'}]}}],
#     'coding': [{'system': 'http://ncimeta.nci.nih.gov',
#       'code': 'C15329',
#       'display': 'Surgical Procedure'},
#      {'system': 'https://hospital.org/TumorDocumentation/Operation/OPS',
#       'version': 'OPS301_2016',
#       'code': '5-402.1x'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'performedDateTime': '2016-05-30',
#    'reasonCode': [{'coding': [{'system': 'http://hospital.org/fhir/CodeSystem/nngm/intention-therapie',
#        'code': 'palliative',
#        'display': 'palliative'}]}]}},
#  {'resource': {'resourceType': 'procedure',
#    'id': '6f6d3f7d-0d37-47ed-bca2-29eb6502b0b4',
# ...
#       'code': 'B1AAYVLAAA'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2016-11-08',
#    'problem': [{'reference': 'Condition/c56c2dfd-4a9c-4621-94bc-47b23dede278'}],
#    'investigation': [{'item': [{'reference': 'Procedure/cf77b499-d83f-4b71-8944-447cc3760d00'}]},
#     {'item': [{'reference': 'Procedure/918524ef-1450-4940-a9d7-0d5236e7b950'}]},
#     {'item': [{'reference': 'Procedure/12ffed2b-6b5b-4867-bb99-ff15ac9de090'}]},
#     {'item': [{'reference': 'Procedure/7c4d30f6-36ed-4903-926c-1d19daa3d7bc'}]},
#     {'item': [{'reference': 'Procedure/a534dfe0-56b0-408c-a19e-e7d676b75f7f'}]},
#     {'item': [{'reference': 'Procedure/f70f9c6e-2ac7-40c0-aeab-2c9ccadae0b0'}]},
#     {'item': [{'reference': 'Procedure/1dfdee66-fe97-43f8-ac53-a92bb17c3268'}]},
#     {'item': [{'reference': 'Procedure/efc6f6d7-65f5-48ce-9d7e-284763d82c36'}]},
#     {'item': [{'reference': 'Procedure/a114f888-51c3-4e7a-9dcb-c02ae5dbb30e'}]},
#     {'item': [{'reference': 'Procedure/be262662-5e35-4b6f-88d1-e621faaa3336'}]},
#     {'item': [{'reference': 'Procedure/82d680ad-571a-4c2f-8dac-c991f5b92ce4'}]},
#     {'item': [{'reference': 'Procedure/9f2c81c0-3d1a-4f03-8a01-9304c5c626ba'}]},
#     {'item': [{'reference': 'Procedure/deb947b4-63c7-467d-ba82-692e27cf0044'}]},
#     {'item': [{'reference': 'Procedure/19f2068f-5fb7-40af-9958-85d73636fcd8'}]},
#     {'item': [{'reference': 'Procedure/c9368a9b-e9ac-4cb0-80d2-d0fe1ca7c455'}]},
#     {'item': [{'reference': 'Procedure/f4c502fe-53a6-4d05-b812-72db38a89375'}]},
#     {'item': [{'reference': 'Procedure/5f70544a-d452-4000-adb7-96cee57918db'}]},
#     {'item': [{'reference': 'Procedure/57e4c96a-2e40-487d-a1bb-03f11bbb45a3'}]},
#     {'item': [{'reference': 'Procedure/10cc5fa1-74ef-47ff-8f5b-47f8077b51ec'}]},
#     {'item': [{'reference': 'Procedure/f48e3784-338b-4b05-800a-e7026afafd45'}]},
#     {'item': [{'reference': 'Procedure/22105729-134e-4e2f-9928-9e8c53b33eb1'}]},
#     {'item': [{'reference': 'Procedure/a0abb88d-77eb-4905-9618-fcde7b30049d'}]},
#     {'item': [{'reference': 'Procedure/a89209b1-a4a4-4a64-9fbe-21938733b4ea'}]},
#     {'item': [{'reference': 'Procedure/ff50c079-4942-4f19-8661-00d5b4b4ebf4'}]},
#     {'item': [{'reference': 'Procedure/7613d341-1400-4bf1-bb43-cfbc1f046fe1'}]},
#     {'item': [{'reference': 'Procedure/1ff6e10c-48f1-40b8-8c76-29769c6a9220'}]},
#     {'item': [{'reference': 'Procedure/baa0f6ce-18bf-43f3-9041-d844acbe8fc5'}]},
#     {'item': [{'reference': 'Procedure/e5b26d9a-e273-41de-9819-8e66e16d9856'}]},
#     {'item': [{'reference': 'Procedure/d1ea7af0-9b5f-4832-8ba2-03cbed1c3fe6'}]},
#     {'item': [{'reference': 'Procedure/b5edc867-3381-44a9-bdab-0914700250e0'}]},
#     {'item': [{'reference': 'Procedure/b0c7c4c3-ec14-4e25-8518-047abf2a62ba'}]},
#     {'item': [{'reference': 'Procedure/3437ecc4-f2c9-40d1-952b-b5389f35a8e8'}]},
#     {'item': [{'reference': 'Procedure/8b17c74d-3fd4-41e2-94d1-036aa5c246aa'}]},
#     {'item': [{'reference': 'Procedure/bac8095a-c071-4a89-92fa-b96dabe9a251'}]},
#     {'item': [{'reference': 'Procedure/08992374-3785-4fb0-9a3f-d3cbb3bdd1c0'}]},
#     {'item': [{'reference': 'Procedure/8d0d2224-134a-44f0-9d94-09057af5a06f'}]},
#     {'item': [{'reference': 'Procedure/fc825465-3d5e-4f4a-b0b0-b1b827f7461d'}]},
#     {'item': [{'reference': 'Procedure/cbaa75ca-5e0d-4db1-9d7e-15c5763111c9'}]},
#     {'item': [{'reference': 'Procedure/b6d7863e-10f7-41fd-b685-574a1010a624'}]},
#     {'item': [{'reference': 'Procedure/579922dc-cbac-44d0-8e0e-48e9ac6873db'}]},
#     {'item': [{'reference': 'Procedure/f802b2ee-362e-4ccd-a0b2-945116b15420'}]},
#     {'item': [{'reference': 'Procedure/44aa0076-038b-419e-8fcc-b01be7355d01'}]},
#     {'item': [{'reference': 'Procedure/28cb285b-1524-439d-bb25-9fed0b8cb061'}]},
#     {'item': [{'reference': 'Procedure/db6c2330-74bf-4c34-a649-e301f9202993'}]},
#     {'item': [{'reference': 'Procedure/fe057ac7-8cec-44ac-a681-f73a9617eace'}]},
#     {'item': [{'reference': 'Procedure/b86a86e4-27ec-42f0-90ac-54d9d29151b8'}]},
#     {'item': [{'reference': 'Procedure/b9096113-1664-4f38-8fc4-8127ec7d77bd'}]},
#     {'item': [{'reference': 'Procedure/f362d8e2-447a-46ad-a74d-48251a6b8f5b'}]},
#     {'item': [{'reference': 'Procedure/ad57f3a5-2447-4119-8459-c2141c629885'}]},
#     {'item': [{'reference': 'Procedure/7bc8d0a7-1980-4b5e-a64e-b5a578d04b2e'}]},
#     {'item': [{'reference': 'Procedure/8767ecc7-b209-46b6-939f-0f60ccae4c32'}]},
#     {'item': [{'reference': 'Procedure/0511f495-9f7c-43ed-b6ba-5aba84cfb29d'}]},
#     {'item': [{'reference': 'Procedure/71104d93-27ee-48c4-9225-dc225a9733e5'}]},
#     {'item': [{'reference': 'Procedure/e3c116fd-65b6-4b3b-bdc2-28010586ae59'}]},
#     {'item': [{'reference': 'Procedure/ded3ffb2-d0e9-4092-8aea-cb5849dc9861'}]},
#     {'item': [{'reference': 'Procedure/fa80cc17-2796-47c8-b33f-d69a4af8f6ee'}]},
#     {'item': [{'reference': 'Procedure/54b66c35-6b58-4c46-b558-4386ae454706'}]},
#     {'item': [{'reference': 'Procedure/5f5c5d8d-2a4a-46ff-8bba-2a1678a9c69f'}]},
#     {'item': [{'reference': 'Procedure/9b7347ee-3502-46a7-8d14-72ed99b9561f'}]},
#     {'item': [{'reference': 'Procedure/c7ef51a6-8da6-43ee-b1b0-c72bef49603c'}]},
#     {'item': [{'reference': 'Procedure/8414894f-baf2-4e39-abcb-5cbfd9e55669'}]},
#     {'item': [{'reference': 'Procedure/2fa65d75-f413-412f-b25c-61c8d144ae13'}]},
#     {'item': [{'reference': 'Procedure/2adea5d2-bf2f-449d-8329-bce871618215'}]},
#     {'item': [{'reference': 'Procedure/d90d14a2-a055-4425-9238-aee8c3935409'}]},
#     {'item': [{'reference': 'Procedure/cf931748-666d-4846-be20-01dcc4d64e0a'}]},
#     {'item': [{'reference': 'Procedure/b6e3a0fa-48bb-4279-8853-0cafcf9cd77c'}]},
#     {'item': [{'reference': 'Procedure/fc53b368-63fa-4632-87e3-ca19d4c99a05'}]},
#     {'item': [{'reference': 'Procedure/99d69c71-bd13-47cd-9b7f-794ace53c394'}]},
#     {'item': [{'reference': 'Procedure/f9da4d46-dba1-4ff0-a3ab-d36450301d66'}]},
#     {'item': [{'reference': 'Procedure/2242a6f1-b999-4804-8ec4-a61215bb5124'}]},
#     {'item': [{'reference': 'Procedure/0fd6e7bb-eb79-4860-9d7b-9742eb974eee'}]},
#     {'item': [{'reference': 'Procedure/2a776df7-f008-483f-906f-2eb0a2184ce0'}]},
#     {'item': [{'reference': 'Procedure/b464e431-dac6-48f2-a127-6ba062135823'}]},
#     {'item': [{'reference': 'Procedure/e355364c-e6d3-4002-8dc8-1bb9d4f65ee7'}]},
#     {'item': [{'reference': 'Procedure/954a6a7d-622e-4f8a-8e14-5f71b574fe1a'}]},
#     {'item': [{'reference': 'Procedure/a267a73b-8acb-4752-9333-efc04be5d402'}]},
#     {'item': [{'reference': 'Procedure/698a4c59-f58f-454d-ab3d-916123e4f9c2'}]},
#     {'item': [{'reference': 'Procedure/8a32e670-7ffe-41bd-bd88-9b3c6700cf03'}]},
#     {'item': [{'reference': 'Procedure/450022a3-89f1-431a-9adc-a527846b2adb'}]},
#     {'item': [{'reference': 'Procedure/31e28603-e50a-44d6-80c6-2dee7f884b04'}]},
#     {'item': [{'reference': 'Procedure/0d580454-8ddd-48bb-8ec4-eaa79382a5b8'}]},
#     {'item': [{'reference': 'Procedure/d76be14c-fe96-4aad-b82b-f3236d7401ef'}]},
#     {'item': [{'reference': 'Procedure/f214aef9-2221-4aa0-9604-d396532b4a36'}]},
#     {'item': [{'reference': 'Procedure/9ea9ba8d-4c35-4533-b9fd-e5f490cc40ad'}]},
#     {'item': [{'reference': 'Procedure/3225754b-890c-48bc-ace2-c6b6c771d884'}]},
#     {'item': [{'reference': 'Procedure/2647bbb5-090a-4c1f-ace0-22f3c52a5d8a'}]},
#     {'item': [{'reference': 'Procedure/05bd6d11-942e-47c3-94cc-08b9b237a135'}]},
#     {'item': [{'reference': 'Procedure/5f6c382b-40ad-40f0-a063-f4d25ca32fbc'}]},
#     {'item': [{'reference': 'Procedure/c29cb80f-ea55-4dee-97f8-e8e6688a8016'}]},
#     {'item': [{'reference': 'Procedure/c97e9c81-c352-41ae-bc24-9b036d9558b7'}]},
#     {'item': [{'reference': 'Procedure/7f335409-48ba-4dab-9860-57a5d46a9597'}]},
#     {'item': [{'reference': 'Procedure/6a26472c-f15c-4e45-9f76-331cf625a38e'}]},
#     {'item': [{'reference': 'Procedure/7fe6a520-296c-4b00-833b-af81e28576e0'}]},
#     {'item': [{'reference': 'Procedure/f3dc9017-6b43-4cbe-ba8e-35cefec89270'}]},
#     {'item': [{'reference': 'Procedure/70f19b09-2232-4657-81e1-d954652931b2'}]},
#     {'item': [{'reference': 'Procedure/e560787f-0693-4006-877b-9b450cc465c8'}]},
#     {'item': [{'reference': 'Procedure/fd074a06-02be-4e25-981c-4c3854cd5607'}]},
#     {'item': [{'reference': 'Procedure/7e5526dc-8b04-43c6-8ea4-1e130cfc6f22'}]},
#     {'item': [{'reference': 'Procedure/22438ecc-0c03-40d4-bc24-75188d4df203'}]},
#     {'item': [{'reference': 'Procedure/dac2b3f7-6be9-4f7f-b56a-5722fda2c0c1'}]},
#     {'item': [{'reference': 'Procedure/fc6b9128-8240-43de-a8b1-a2ee352b8bf2'}]},
#     {'item': [{'reference': 'Procedure/c03200f5-d1d5-4ff2-b982-411489fc56ef'}]},
#     {'item': [{'reference': 'Procedure/c3ba5fa8-9390-4d24-9f93-dd8b40b6a3f2'}]},
#     {'item': [{'reference': 'Procedure/34911266-fb02-4c1c-8f66-25a08e682923'}]},
#     {'item': [{'reference': 'Procedure/b1db918b-5a6c-430d-87d6-b603288f8501'}]},
#     {'item': [{'reference': 'Procedure/da5e9502-400d-4050-8e1b-11810a790568'}]},
#     {'item': [{'reference': 'Procedure/d0a45735-5849-485c-9419-569e5639b345'}]},
#     {'item': [{'reference': 'Procedure/b99fddbd-a5c8-445f-ade0-8c7d46dee1cb'}]},
#     {'item': [{'reference': 'Procedure/be7d5edc-021d-4383-aebb-34ebc2fea1a5'}]},
#     {'item': [{'reference': 'Procedure/d92b5abd-a764-4a9c-8017-52946565bb02'}]},
#     {'item': [{'reference': 'Procedure/e9551378-2003-4509-8f16-e8de9578ba11'}]},
#     {'item': [{'reference': 'Procedure/264d671c-fb79-4497-aae1-146d594aaf26'}]},
#     {'item': [{'reference': 'Procedure/1a606c91-309d-49b4-ad94-fda985bc7024'}]},
#     {'item': [{'reference': 'Procedure/17a8d315-e30f-4eeb-9ca3-96d36cb46987'}]},
#     {'item': [{'reference': 'Procedure/5fa28fc4-0b71-4b4c-a393-8192ea38045c'}]},
#     {'item': [{'reference': 'Procedure/71e54ccd-ca0a-4000-ac98-0ccecbf2b511'}]},
#     {'item': [{'reference': 'Procedure/f572918b-8641-4077-b889-76603c8019e6'}]},
#     {'item': [{'reference': 'Procedure/034e5868-6649-4b33-921b-630234185ad1'}]},
#     {'item': [{'reference': 'Procedure/1d29547e-f735-497b-93a2-57f2dccfcda8'}]},
#     {'item': [{'reference': 'Procedure/94672ea4-5775-4450-87a5-17df11f59899'}]},
#     {'item': [{'reference': 'Procedure/e7c37a96-64da-424f-9565-18d1cea7c593'}]},
#     {'item': [{'reference': 'Procedure/f02c4efe-ef0d-41f3-8504-3f1d31e53178'}]},
#     {'item': [{'reference': 'Procedure/cfeb9cbd-777d-4127-9571-1330865326ee'}]},
#     {'item': [{'reference': 'Procedure/d47d0a66-fd5c-44e1-878d-7214ee1a036f'}]},
#     {'item': [{'reference': 'Procedure/e1b38280-5044-4f9c-97d7-0fe80545aa2e'}]},
#     {'item': [{'reference': 'Procedure/b24940ce-4445-445c-8a47-dd70384e5f48'}]},
#     {'item': [{'reference': 'Procedure/80f8b950-1c4b-4ef0-89e3-d15c784bfc55'}]},
#     {'item': [{'reference': 'Procedure/1fb5b0ff-0cd8-4f97-8260-a0528fa2a352'}]},
#     {'item': [{'reference': 'Procedure/2dc01b3b-8178-4fd7-a188-3129e909cc62'}]},
#     {'item': [{'reference': 'Procedure/dc70f225-0d2b-46a2-98b7-676723d17d6a'}]},
#     {'item': [{'reference': 'Procedure/aedf787d-ad39-4add-ab59-b7515a7dfb57'}]},
#     {'item': [{'reference': 'Procedure/bbdafcdc-453c-4d31-af2c-fada59c631b4'}]},
#     {'item': [{'reference': 'Procedure/797d1cd0-dbd0-4e88-bcd6-a669f0ddda47'}]},
#     {'item': [{'reference': 'Procedure/371c0ec1-4067-479a-a2d9-0269a64c005a'}]},
#     {'item': [{'reference': 'Procedure/715c9ae5-a1b1-4c32-9754-e02098347e1b'}]},
#     {'item': [{'reference': 'Procedure/10aef377-be02-42a3-8189-0877033c510c'}]}]}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': 'ec632d68-a3e9-42ac-b26d-156798e0c571',
#    'meta': {'profile': ['http://hospital.org/fhir/StructureDefinition/Observation/nNGM/ecog']},
#    'identifier': [{'system': 'https://hospital.org/Observation/TumorDocumentation/ECOG'}],
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'survey'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '89247-1',
#       'display': 'ECOG performance status score'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2019-05-28',
#    'issued': '2019-05-28T22:59:17.129+00:00',
#    'valueCodeableConcept': {'coding': [{'system': 'http://loinc.org',
#       'code': 'LA9622-7',
#       'display': 'Fully active, able to carry on all pre-disease performance without restriction'}]}}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '24d6447d-e83d-4dc6-b470-9f9606105c15',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties'}],
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties',
#       'code': 'B1AAYPBKDB',
#       'display': 'capsule breakthrough'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2016-06-01',
#    'valueBoolean': True}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '68e0a38e-8f68-47d5-8253-40767bf274b8',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties'}],
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties',
#       'code': 'B1AAYPBKDB',
#       'display': 'capsule breakthrough'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2014-10-13',
#    'valueBoolean': True}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '3a01a30b-01ab-4906-a864-4ec93cb9ec79',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties'}],
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties',
#       'code': 'B1AAYPBULZ',
#       'display': 'ulceration'},
#      {'system': 'http://snomed.info/sct',
#       'code': '56208002',
#       'display': 'ulceration'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2013-12',
#    'valueBoolean': True}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '5c7b2658-a88e-407f-ab88-8f09e696d6f8',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties'}],
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties',
#       'code': 'B1AAYPBREGRE',
#       'display': 'regression'},
#      {'system': 'http://loinc.org',
#       'code': '92834-1',
#       'display': 'Tumor regression at peripheral margin [Presence] in skin melanoma'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2013-12',
#    'valueBoolean': False}},
#  {'resource': {'resourceType': 'surveillance',
#    'id': '655852dc-9508-4595-ae51-425218d1dfc3',
#    'identifier': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties'}],
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Lab'}]}],
#    'code': {'coding': [{'system': 'https://hospital.org/TumorDocumentation/DCP08/PathologyReport/TumorProperties',
#       'code': 'B1AAYPBTUDI',
#       'display': 'tumor thickness in mm'}]},
#    'subject': {'reference': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b'},
#    'effectiveDateTime': '2013-12',
#    'valueQuantity': {'value': 1.9,
#     'unit': 'millimeter',
#     'system': 'http://unitsofmeasure.org',
#     'code': 'mm'}}}]

# %%
## Date perturbation
from perturbDates import dateChanger
dc = dateChanger(dateFields=[
    ['resource','effectiveDateTime'],
    ['resource','onsetDateTime'],
    ['resource','performedDateTime'],
    ['resource','performedPeriod','start'],
    ['resource','performedPeriod','end'],
    ['resources','effectivePeriod','start'],
    ['resource','effectivePeriod','end']
    
    
    ]) # create an instance of dateChanger
dc.addRandomNoise(resources)
resources

# %%
# adds a field to a dictionary and returns the dictionary
def addField(x, addfun, fieldName):
    x[fieldName] = addfun(x)
    return x

# %%
## STAGES
stages = [addField(x, lambda x: "p","p_or_c") for x in ptnm_extractor.extract(resources)]
stages += [addField(x, lambda x: "c","p_or_c") for x in ctnm_extractor.extract(resources)]
stages.sort(key = lambda x: x['dt_record'])

stages = groupResources(stages, "dt_record")

# we only want to keep one resource per date
def keepHighestPriority(resources, field, priorities):
    highestPrio = len(priorities) + 10
    for resource in resources:
        currentPrio = priorities.index(resource[field])
        if currentPrio < highestPrio:
             highestPrio = currentPrio
    highestPrio = priorities[highestPrio]
    return [x for x in resources if x[field] == highestPrio]

stages = [keepHighestPriority(x, 'p_or_c', ['p','c']) for x in stages]
stages = [keepHighestPriority(x, 'cat_version', ['AJCC2017','AJCC2009',None]) for x in stages]

# after checking the resources, we can safely combine them
stages = [combineResources(x) for x in stages]

# Some functions to make the output beautiful

# -> put in a resource with stage information -> this function outputs a string easy to read for doctors
# -> will be used later
def printStage(x):
    t, n, m = x.get('tstage',' k.A. '), x.get('nstage',' k.A. '), x.get('mstage',' k.A. ')
    tnm = x.get('tnm_stage','')
    ver = x.get('cat_version')
    if ver is None:
        ver = "k.A."
    porc = x.get('p_or_c')
    r = x.get('residual_state','')
    senPos = x.get('snodes_postive',"")
    senTest = x.get('snodes_examined',"?")
    renPos = x.get('rnodes_positive',"")
    renTest = x.get('rnodes_examined',"?")
    
    res = f"Version: {ver}, {porc}{tnm} T{t}N{n}M{m}{r}"
    if senPos != "":
        res += f", Sentinel: {senPos}+/{senTest}"
    if renPos != "":
        res += f", Regional Lymphnodes: {renPos}+/{renTest}"
    return res


# add nice field to print and the next date as stop date
stages = [addField(x, printStage, "val_print") for x in stages]
for i in range(len(stages)-1):
    stages[i]['dt_end'] = stages[i+1]['dt_record']
stages[-1]['dt_end'] = "2019-06-22" #  2019-06-21 is the date he deceased

# Add code to include code information on the stages
json_pat = open(json_path_to_cleaned_patient)
json_pat = json.load(json_pat)
primary_stage = getPrimaryTumor(json_pat)
cancer_code = primary_stage[0]['ICD10_2019_cancer_code']

def add_to_beginning(my_list, entry):
    my_list.insert(0, entry)
    return my_list

stages = add_to_beginning(stages, {'ICD10_2019_cancer_code':cancer_code})

stages
# Out:
# [{'ICD10_2019_cancer_code': 'C43.7'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-04-14',
#   'cat_version': None,
#   'tnm_stage': 'III',
#   'tstage': '2 B',
#   'nstage': '0',
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIII T2 BN0M k.A. ',
#   'dt_end': '2014-05-03'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-05-03',
#   'tnm_stage': 'IIIB',
#   'cat_version': 'AJCC2017',
#   'tstage': '2 B',
#   'nstage': '1a',
#   'mstage': '0',
#   'p_or_c': 'c',
#   'val_print': 'Version: AJCC2017, cIIIB T2 BN1aM0',
#   'dt_end': '2014-05-23'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-05-23',
#   'cat_version': None,
#   'tnm_stage': 'IIIB',
#   'tstage': '2 B',
#   'nstage': '1a',
#   'snodes_postive': 1,
#   'snodes_examined': 1,
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIIIB T2 BN1aM k.A. , Sentinel: 1+/1',
#   'dt_end': '2015-02-20'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-02-20',
#   'cat_version': None,
#   'tnm_stage': 'IIIC',
#   'tstage': '2 B',
#   'nstage': '2 B',
#   'rnodes_positive': 1,
#   'rnodes_examined': 1,
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIIIC T2 BN2 BM k.A. , Regional Lymphnodes: 1+/1',
#   'dt_end': '2015-04-03'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-04-03',
#   'cat_version': None,
#   'tnm_stage': 'IIIC',
#   'tstage': '2 B',
#   'nstage': '2 B',
#   'rnodes_positive': 1,
#   'rnodes_examined': 7,
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIIIC T2 BN2 BM k.A. , Regional Lymphnodes: 1+/7',
#   'dt_end': '2016-05-02'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-05-02',
#   'cat_version': None,
#   'tnm_stage': 'IIIC',
#   'tstage': '2 B',
#   'nstage': '2c',
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIIIC T2 BN2cM k.A. ',
#   'dt_end': '2016-09-29'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-09-29',
#   'cat_version': None,
#   'tnm_stage': 'IV',
#   'tstage': '2 B',
#   'nstage': '3',
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIV T2 BN3M k.A. ',
#   'dt_end': '2016-10-17'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-10-17',
#   'cat_version': None,
#   'tnm_stage': 'IV',
#   'tstage': '2 B',
#   'nstage': '3',
#   'rnodes_positive': 2,
#   'rnodes_examined': 4,
#   'p_or_c': 'p',
#   'val_print': 'Version: k.A., pIV T2 BN3M k.A. , Regional Lymphnodes: 2+/4',
#   'dt_end': '2019-06-22'}]

# %%
examinations = examinations_ext.extract(resources)
examinations = groupResources(examinations, "dt_record")
examinations = [combineResources(x) for x in examinations]
examinations
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-06-23',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': ['Initial presentation', 'Treatment planning']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-09-08',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'physical exam'],
#   'cat_reasons': 'Follow-up'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-12-28',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Follow-up']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-02-14',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Follow-up']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-03-06',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': ['Treatment planning', 'medical care']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-03-14',
#   'cat_examination_type': ['Laboratory procedure',
#    'Magnetic resonance imaging',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure',
#    'Treatment planning',
#    'medical care']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-04-29',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': ['Treatment planning', 'medical care']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-06-24',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'physical exam'],
#   'cat_reasons': 'Follow-up'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-09-09',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'Magnetic resonance imaging',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Follow-up']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-01-05',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'physical exam'],
#   'cat_reasons': 'Follow-up'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-03-02',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'Magnetic resonance imaging',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Follow-up']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-04-22',
#   'cat_examination_type': ['Ultrasonography', 'physical exam'],
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-06-28',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'physical exam'],
#   'cat_reasons': 'Initial presentation'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-09-10',
#   'cat_examination_type': ['physical exam',
#    'Laboratory procedure',
#    'Magnetic resonance imaging',
#    'computed tomography',
#    'Ultrasonography'],
#   'cat_reasons': ['Diagnostic or staging procedure',
#    'Treatment planning',
#    'medical care']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-10-21',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': ['Treatment planning', 'medical care']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-11-11',
#   'cat_examination_type': ['Laboratory procedure', 'computed tomography'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Therapeutic Procedure']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-11-16',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-11-29',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-12-05',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-12-20',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-12-22',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-01-12',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-01-22',
#   'cat_examination_type': 'Laboratory procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-01-23',
#   'cat_examination_type': 'Magnetic resonance imaging',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-01-24',
#   'cat_examination_type': 'Laboratory procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-01-28',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-02-04',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-02-05',
#   'cat_examination_type': ['Laboratory procedure',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-03-07',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-03-09',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-03-25',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-04-21',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Follow-up'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-05-30',
#   'cat_examination_type': ['Laboratory procedure',
#    'Magnetic resonance imaging',
#    'computed tomography'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Treatment planning']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-06-01',
#   'cat_examination_type': 'Ultrasonography',
#   'cat_reasons': 'Treatment planning'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-06-17',
#   'cat_examination_type': 'Positron Emission Tomography',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-07-04',
#   'cat_examination_type': 'Magnetic resonance imaging',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-08-29',
#   'cat_examination_type': 'Magnetic resonance imaging',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-09-30',
#   'cat_examination_type': 'computed tomography',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-10-24',
#   'cat_examination_type': 'Electrocardiography',
#   'cat_reasons': 'Treatment planning'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-11-15',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-12-14',
#   'cat_examination_type': 'Magnetic resonance imaging',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-01-19',
#   'cat_examination_type': ['computed tomography', 'Electrocardiography'],
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-01-24',
#   'cat_examination_type': ['Laboratory procedure',
#    'Ultrasonography',
#    'physical exam']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-02-16',
#   'cat_examination_type': 'Laboratory procedure',
#   'cat_reasons': 'medical care'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-03-07',
#   'cat_examination_type': ['Laboratory procedure',
#    'Magnetic resonance imaging',
#    'computed tomography',
#    'Ultrasonography'],
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-03-28',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': 'medical care'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-05-14',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-06-05',
#   'cat_examination_type': 'computed tomography',
#   'cat_reasons': ['Diagnostic or staging procedure', 'Therapeutic Procedure']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-07-01',
#   'cat_examination_type': ['Laboratory procedure',
#    'Magnetic resonance imaging'],
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-08-02',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-10-01',
#   'cat_examination_type': ['Laboratory procedure',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Therapeutic Procedure']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-10-21',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-01-15',
#   'cat_examination_type': ['Laboratory procedure',
#    'Magnetic resonance imaging',
#    'computed tomography',
#    'Electrocardiography',
#    'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-03-15',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-03-23',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-05-06',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-06-11',
#   'cat_examination_type': ['Magnetic resonance imaging',
#    'computed tomography'],
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-07-09',
#   'cat_examination_type': 'Laboratory procedure',
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-07-30',
#   'cat_examination_type': 'Magnetic resonance imaging',
#   'cat_reasons': 'Diagnostic or staging procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-08-12',
#   'cat_examination_type': 'Laboratory procedure',
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-08-31',
#   'cat_examination_type': ['Laboratory procedure',
#    'computed tomography',
#    'physical exam'],
#   'cat_reasons': ['Diagnostic or staging procedure', 'Therapeutic Procedure']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-10-03',
#   'cat_examination_type': ['Laboratory procedure', 'physical exam'],
#   'cat_reasons': 'Therapeutic Procedure'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-10-04',
#   'cat_examination_type': 'physical exam',
#   'cat_reasons': 'Treatment planning'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-10-06',
#   'cat_examination_type': 'physical exam'}]

# %%
radio_therapy = radiotherapy_ext.extract(resources)
radio_therapy = [combineResources(x) for x in groupResources(radio_therapy, "dt_start")] # deletes one duplicate
radio_therapy
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_start': '2016-10-17',
#   'dt_end': '2016-11-08',
#   'cat_intention': ['palliative', 'adjuvant'],
#   'cat_status': 'completed',
#   'cat_reason_end': 'regular ending'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_start': '2017-07-10',
#   'dt_end': '2017-07-18',
#   'cat_intention': 'palliative',
#   'cat_status': 'completed',
#   'cat_reason_end': 'regular ending'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_start': '2019-07-31',
#   'dt_end': '2019-07-31',
#   'cat_intention': 'palliative',
#   'cat_status': 'completed',
#   'cat_reason_end': 'Miscellaneous'}]

# %%
progresses = progress_extractor.extract(resources)
progresses = [combineResources(x) for x in groupResources(progresses, "dt_record")]
progresses
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-09-08',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-12-28',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'questionable finding',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-02-14',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-03-14',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'No distant metastases detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-06-24',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-09-09',
#   'cat_progress_overall': 'Tumor-free (after resection)',
#   'cat_progress_metastases': 'No distant metastases detectable',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-01-05',
#   'cat_progress_primary': 'no tumor detectable',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-03-02',
#   'cat_progress_overall': 'Tumor-free (after resection)',
#   'cat_progress_metastases': 'No distant metastases detectable',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-04-22',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-06-28',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-09-10',
#   'cat_progress_primary': 'no tumor detectable',
#   'cat_progress_overall': 'Progression (tumor growth > 25% and/or progression of tumor disease)',
#   'cat_progress_metastases': 'New distant metastasis(es) or metastasis recurrence',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-11-11',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-01-23',
#   'cat_progress_overall': 'No change (tumor reduction < 50% or increase < 25%)',
#   'cat_progress_metastases': 'Distant Metastases No Change'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-02-05',
#   'cat_progress_metastases': 'Distant metastases residuals'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-05-30',
#   'cat_progress_overall': 'Progression (tumor growth > 25% and/or progression of tumor disease)',
#   'cat_progress_metastases': 'New distant metastasis(es) or metastasis recurrence',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-06-01',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-06-17',
#   'cat_progress_metastases': 'No distant metastases detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-07-04',
#   'cat_progress_metastases': 'Distant Metastasis Progress'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-08-29',
#   'cat_progress_overall': 'Progression (tumor growth > 25% and/or progression of tumor disease)',
#   'cat_progress_metastases': 'Distant Metastasis Progress'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-09-30',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'No distant metastases detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2017-12-14',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-01-19',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-01-24',
#   'cat_progress_nodes': 'No lymph node involvement detectable'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-03-07',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'questionable finding',
#   'cat_progress_nodes': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-06-05',
#   'cat_progress_overall': 'No change (tumor reduction < 50% or increase < 25%)',
#   'cat_progress_metastases': 'Distant Metastases No Change'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-07-01',
#   'cat_progress_overall': 'No change (tumor reduction < 50% or increase < 25%)',
#   'cat_progress_metastases': 'Distant Metastases No Change'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2018-10-01',
#   'cat_progress_overall': 'No change (tumor reduction < 50% or increase < 25%)',
#   'cat_progress_metastases': 'Distant Metastases No Change'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-01-15',
#   'cat_progress_overall': 'No change (tumor reduction < 50% or increase < 25%)',
#   'cat_progress_metastases': 'Distant Metastases No Change'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-06-11',
#   'cat_progress_overall': 'Not applicable, as treatment is part of a multimodal concept and this is not yet completed',
#   'cat_progress_metastases': 'questionable finding'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-07-30',
#   'cat_progress_overall': 'No change (tumor reduction < 50% or increase < 25%)',
#   'cat_progress_metastases': 'Distant Metastases No Change'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2019-08-31',
#   'cat_progress_metastases': 'No distant metastases detectable'}]

# %%
medis = medi_extractor.extract(resources)
medis.sort(key=lambda x: x['dt_start'])
medis
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'cat_drugtype': 'Unknown',
#   'dt_start': '2016-07-13T19:41:57+00:00',
#   'dt_end': '2017-03-07',
#   'cat_intention': 'palliative',
#   'cat_status': 'stopped',
#   'cat_reason_end': 'Discontinuation due to side effects',
#   'num_quantity': 5},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'cat_drugtype': 'Unknown',
#   'dt_start': '2017-06-06T19:41:57+00:00',
#   'dt_end': '2019-10-27',
#   'cat_intention': 'palliative',
#   'cat_status': 'stopped',
#   'cat_reason_end': 'Miscellaneous'}]

# %%
# unknown is stupid for demonstration -> change it to Nivo+Ipi and Pembro
medis[0]['cat_drugtype'] = "Nivo+Ipi"
medis[1]['cat_drugtype'] = "Pembrolizumab"
medis
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'cat_drugtype': 'Nivo+Ipi',
#   'dt_start': '2016-07-13T19:41:57+00:00',
#   'dt_end': '2017-03-07',
#   'cat_intention': 'palliative',
#   'cat_status': 'stopped',
#   'cat_reason_end': 'Discontinuation due to side effects',
#   'num_quantity': 5},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'cat_drugtype': 'Pembrolizumab',
#   'dt_start': '2017-06-06T19:41:57+00:00',
#   'dt_end': '2019-10-27',
#   'cat_intention': 'palliative',
#   'cat_status': 'stopped',
#   'cat_reason_end': 'Miscellaneous'}]

# %%
properties_prim = tproperties_extractor.extract(resources)
properties_prim = [combineResources(x) for x in groupResources(properties_prim, "dt_record")]
properties_prim
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2014-04-14',
#   'flg_ulcerated': True,
#   'flg_regression': False,
#   'no_tumor_thickness': 1.9},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2015-02-20',
#   'flg_transcapsular': True},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-10-17',
#   'flg_transcapsular': True}]

# %%
oncogenes = getExtractorOncogenes().extract(resources)
oncogenes = [x for x in oncogenes if x['cat_gene'] in ['TERT result','BRAF result',
                                                       'NRAS result','NF1 result']] # should be the most relevant

# make outcome nice
def printGene(x):
    res = x['cat_gene'][:-8]
    if x['flg_mutated']:
        res += 'mutation'
        freq = x.get('num_frequency',-1)
        if freq > 0:
            res += " (Frequency " + str(freq) + ")"
    else:
        res += 'wildtype'
    return res
        
oncogenes = [addField(x, printGene, 'val_print') for x in oncogenes]
for onco in oncogenes:
    onco.pop('cat_gene')
    onco.pop('flg_mutated')
    onco.pop('num_frequency', None)
oncogenes = [combineResources(x) for x in groupResources(oncogenes, 'dt_record')]
oncogenes
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2013-05-05',
#   'val_print': ['BRAwildtype', 'NRAwildtype']},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'dt_record': '2016-05-02',
#   'val_print': ['NFwildtype', 'BRAwildtype', 'TERwildtype', 'NRAwildtype']}]

# %%
patientinfo = [x for x in resources if x['resource']['resourceType'] == 'patient']
patientinfo = patientinfo[0]['resource']
patientinfo.keys()
patientinfo.pop('meta', None)
patientinfo.pop('managingOrganization', None)
patientinfo.pop('identifier', None)
patientinfo
# Out:
# {'resourceType': 'patient',
#  'id': '02b4f296-3cfc-4e2b-a35c-70c83712160b',
#  'gender': 'female',
#  'birthDate': '1961-05-30',
#  'deceasedDateTime': '2019-06-21T19:41:57.025+02:00'}

# %%
# Make the Careplan entry
careplan_simp = getCareplan(json_pat)
careplan_simp
# Out:
# [{'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2019-02-06',
#   'careplan_name': 'radiotherapy',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2019-02-06',
#   'careplan_name': 'Targeted Substances',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2018-02-21',
#   'careplan_name': 'Targeted Substances',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2017-11-08',
#   'careplan_name': 'Targeted Substances',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2017-08-30',
#   'careplan_name': 'Targeted Substances',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2017-08-09',
#   'careplan_name': 'Diagnosis',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2017-05-24',
#   'careplan_name': 'Targeted Substances',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2017-02-08',
#   'careplan_name': 'radiotherapy',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2017-01-11',
#   'careplan_name': 'Diagnosis',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2016-07-06',
#   'careplan_name': 'Antibody/Immunotherapy',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2016-05-12',
#   'careplan_name': 'radiotherapy',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2016-05-02',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2016-05-02',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2015-12-10',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'palliative'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2014-11-23',
#   'careplan_name': 'Targeted Substances',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2014-10-29',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2014-10-06',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'palliative',
#   'careplan_type': 'recurrence therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2014-02-12',
#   'careplan_name': 'Antibody/Immunotherapy',
#   'careplan_intention': 'Curative'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2014-02-06',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'Curative',
#   'careplan_type': 'primal therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2014-01',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'Curative',
#   'careplan_type': 'primal therapy'},
#  {'patid': 'Patient/02b4f296-3cfc-4e2b-a35c-70c83712160b',
#   'time_of_careplan': '2013-12',
#   'careplan_name': 'surgery',
#   'careplan_intention': 'Curative'}]

# %%
json4demonstration = {
    'patient_info': patientinfo,
    'stages': stages,
    'examinations': examinations,
    'radiotherapy': radio_therapy,
    'progresses': progresses,
    'medication': medis,
    'properties_primary': properties_prim,
    'oncogenes': oncogenes,
    'careplans': careplan_simp
    
}

# %%
with open('example_patient_pub.json', 'w', encoding='utf-8') as f:
    json.dump(json4demonstration, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### We should double check again but now in the example_patient json file all the green-highlighted data are presented. That means we have the pipeline for fhir data --> simplified json
